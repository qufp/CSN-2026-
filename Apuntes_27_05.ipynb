# %% [markdown]
# <a href="https://colab.research.google.com/github/qufp/CSN-2026-/blob/main/Apuntes_27_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class heroe:
  def __init__(self, nombre, poder, energia):
    self

# %% [markdown]
# **Actividad**

# %%
class TarjetaCredito:
  def __init__(self, banco, limite):
    self.banco = banco
    self.limite = limite

  def  mostrat_limite(self):
    print(f"Tarjeta de {self.banco} con lim")

class
